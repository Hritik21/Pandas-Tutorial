# %%
Employee={
    'Id':['E01','E02','E03','E04','E05','E06','E07','E08'],
    'Name' : ['John', 'Jerry' , 'Tom', 'Herry', 'Joy','Justin' ,'Richie','Rony'],
    'Email' : ['john@gmail.com','jerry@gmail.com','tom@gmail.com','herry@gmail.com','joy@gmail.com','justin@gmail.com','richie@gmail.com','rony@gmail.com']
}

# %%
import pandas as pd
df=pd.DataFrame(Employee)

# %%
df
# Out:
#     Id    Name             Email
# 0  E01    John    john@gmail.com
# 1  E02   Jerry   jerry@gmail.com
# 2  E03     Tom     tom@gmail.com
# 3  E04   Herry   herry@gmail.com
# 4  E05     Joy     joy@gmail.com
# 5  E06  Justin  justin@gmail.com
# 6  E07  Richie  richie@gmail.com
# 7  E08    Rony    rony@gmail.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'Email'], dtype='object')

# %%
df.columns=['emp_id','first_name','emp_email']

# %%
df
# Out:
#   emp_id first_name         emp_email
# 0    E01       John    john@gmail.com
# 1    E02      Jerry   jerry@gmail.com
# 2    E03        Tom     tom@gmail.com
# 3    E04      Herry   herry@gmail.com
# 4    E05        Joy     joy@gmail.com
# 5    E06     Justin  justin@gmail.com
# 6    E07     Richie  richie@gmail.com
# 7    E08       Rony    rony@gmail.com

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   EMP_ID FIRST_NAME         EMP_EMAIL
# 0    E01       John    john@gmail.com
# 1    E02      Jerry   jerry@gmail.com
# 2    E03        Tom     tom@gmail.com
# 3    E04      Herry   herry@gmail.com
# 4    E05        Joy     joy@gmail.com
# 5    E06     Justin  justin@gmail.com
# 6    E07     Richie  richie@gmail.com
# 7    E08       Rony    rony@gmail.com

# %%
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#   EMP ID FIRST NAME         EMP EMAIL
# 0    E01       John    john@gmail.com
# 1    E02      Jerry   jerry@gmail.com
# 2    E03        Tom     tom@gmail.com
# 3    E04      Herry   herry@gmail.com
# 4    E05        Joy     joy@gmail.com
# 5    E06     Justin  justin@gmail.com
# 6    E07     Richie  richie@gmail.com
# 7    E08       Rony    rony@gmail.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   emp id first name         emp email
# 0    E01       John    john@gmail.com
# 1    E02      Jerry   jerry@gmail.com
# 2    E03        Tom     tom@gmail.com
# 3    E04      Herry   herry@gmail.com
# 4    E05        Joy     joy@gmail.com
# 5    E06     Justin  justin@gmail.com
# 6    E07     Richie  richie@gmail.com
# 7    E08       Rony    rony@gmail.com

# %%
df.rename(columns={'emp id':'id'},inplace=True)

# %%
df
# Out:
#     id first name         emp email
# 0  E01       John    john@gmail.com
# 1  E02      Jerry   jerry@gmail.com
# 2  E03        Tom     tom@gmail.com
# 3  E04      Herry   herry@gmail.com
# 4  E05        Joy     joy@gmail.com
# 5  E06     Justin  justin@gmail.com
# 6  E07     Richie  richie@gmail.com
# 7  E08       Rony    rony@gmail.com
